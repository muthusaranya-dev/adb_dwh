# %% [markdown]
# ## # Create customer source crm

# %%
# %sql
CREATE OR REPLACE TABLE bronze.customers_source_crm
USING CSV
OPTIONS (header "true", inferSchema "true")
LOCATION "/mnt/raw/source_crm/cust_info.csv"

# %%
# %sql
CREATE OR REPLACE TABLE bronze.prd_source_crm
USING CSV
OPTIONS (header "true", inferSchema "true")
LOCATION "/mnt/raw/source_crm/prd_info.csv.csv"

# %%
# %sql
CREATE OR REPLACE TABLE bronze.sales_source_crm
USING CSV
OPTIONS (header "true", inferSchema "true")
LOCATION "/mnt/raw/source_crm/sales_details.csv"
